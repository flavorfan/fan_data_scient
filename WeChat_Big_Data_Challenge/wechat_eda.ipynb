# %%
import pandas as pd

# %% [markdown]
# # user_action

# %% [markdown]
# * device  1,2 有一个 apple， 一个 android
# * bool play > feed.long   ms，属于重播， 百分比情况
#     * 播放完并且重播，大概率会评论，转发等 action
#
# * 用户已收藏，关注不会再收藏关注

# %% [markdown]
# ## overview

# %%
df_user_action = pd.read_csv('data/wechat_algo_data1/user_action.csv')

# %%
df_user_action
# Out:
#          userid  feedid  date_  device  read_comment  comment  like    play  \
# 0             8   71474      1       1             0        0     1     500
# 1             8   73916      1       1             0        0     0     250
# 2             8   50282      1       1             0        0     0     750
# 3             8   11391      1       1             0        0     1    3750
# 4             8   27349      1       1             0        0     0     250
# ...         ...     ...    ...     ...           ...      ...   ...     ...
# 7317877  250236   72813     12       2             0        0     0    6369
# 7317878  250236   52019     12       2             0        0     0   13212
# 7317879  250236   51045     12       2             0        0     0       0
# 7317880  250236   46881     12       2             0        0     0       0
# 7317881  250236   53804     12       2             1        0     0  160560
#
#            stay  click_avatar  forward  follow  favorite
# ...

# %%
df_user_action.describe()
# Out:
#              userid        feedid         date_        device  read_comment  \
# count  7.317882e+06  7.317882e+06  7.317882e+06  7.317882e+06  7.317882e+06
# mean   1.249679e+05  5.669863e+04  7.801455e+00  1.765396e+00  3.501587e-02
# std    7.239444e+04  3.278194e+04  4.063833e+00  4.237514e-01  1.838199e-01
# min    8.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    6.133000e+04  2.814900e+04  4.000000e+00  2.000000e+00  0.000000e+00
# 50%    1.256370e+05  5.682500e+04  8.000000e+00  2.000000e+00  0.000000e+00
# 75%    1.878630e+05  8.522900e+04  1.100000e+01  2.000000e+00  0.000000e+00
# max    2.502360e+05  1.128710e+05  1.400000e+01  2.000000e+00  1.000000e+00
#
#             comment          like          play          stay  click_avatar  \
# count  7.317882e+06  7.317882e+06  7.317882e+06  7.317882e+06  7.317882e+06
# mean   4.046253e-04  2.580487e-02  2.631760e+04  3.101158e+04  7.533327e-03
# ...

# %%
df_user_action.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7317882 entries, 0 to 7317881
# Data columns (total 13 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   userid        int64
#  1   feedid        int64
#  2   date_         int64
#  3   device        int64
#  4   read_comment  int64
#  5   comment       int64
#  6   like          int64
#  7   play          int64
#  8   stay          int64
#  9   click_avatar  int64
#  10  forward       int64
#  11  follow        int64
#  12  favorite      int64
# dtypes: int64(13)
# memory usage: 725.8 MB

# %%
df_user_action.nunique()
# Out:
# userid           20000
# feedid           96564
# date_               14
# device               2
# read_comment         2
# comment              2
# like                 2
# play            201721
# stay            220343
# click_avatar         2
# forward              2
# follow               2
# favorite             2
# dtype: int64

# %%
df_user_action.device.value_counts()
# Out:
# 2    5601074
# 1    1716808
# Name: device, dtype: int64

# %%
df_user_action.date_.value_counts().sort_index()
# Out:
# 1     478489
# 2     461842
# 3     543566
# 4     504623
# 5     444828
# 6     472726
# 7     480460
# 8     500120
# 9     512466
# 10    596886
# 11    614175
# 12    532038
# 13    566627
# 14    609036
# Name: date_, dtype: int64

# %%
(
    df_user_action
    .groupby(['userid','device']).agg(cnt=('device','count'))
    .reset_index()
    .groupby('userid').agg(cnt2=('device','count'))
    .query('cnt2 == 2')
)
# Out:
#         cnt2
# userid
# 4674       2
# 5119       2
# 5279       2
# 5786       2
# 5907       2
# ...      ...
# 243101     2
# 243267     2
# 244321     2
# 244796     2
# 249759     2
#
# [159 rows x 1 columns]

# %% [markdown]
# ## columns

# %%
df_user_action.columns.to_list()
# Out:
# ['userid',
#  'feedid',
#  'date_',
#  'device',
#  'read_comment',
#  'comment',
#  'like',
#  'play',
#  'stay',
#  'click_avatar',
#  'forward',
#  'follow',
#  'favorite']

# %% [markdown]
# # feed_info

# %%
df_feed_info = pd.read_csv('data/wechat_algo_data1/feed_info.csv')

# %%
df_feed_info.head().T
# Out:
#                                                                       0  \
# feedid                                                            43549
# authorid                                                           6165
# videoplayseconds                                                     38
# description           104741 122649 8109 117252 65632 23463 118668 4...
# ocr                   139499 59421 82007 142955 27736 83577 52394 11...
# asr                   142955 27736 83577 103956 32010 34170 89740 90...
# bgm_song_id                                                     19356.0
# bgm_singer_id                                                   11703.0
# manual_keyword_list                                    15506;7715;17582
# machine_keyword_list                         26334;219;25209;7715;18541
# manual_tag_list                                            81;269;159;6
# machine_tag_list      269 0.8525666;81 0.8525666;8 1.1e-07;306 0.0;2...
# ...

# %%
df_feed_info
# Out:
#         feedid  authorid  videoplayseconds  \
# 0        43549      6165                38
# 1        77432      9386                60
# 2        12921      2996                15
# 3        34538     12577                18
# 4        75414      7185                16
# ...        ...       ...               ...
# 106439  104384     14898                10
# 106440   91514      5356                15
# 106441   69742     12148                23
# 106442   61540     14708                43
# 106443   89334     15775                32
#
#                                               description  \
# 0       104741 122649 8109 117252 65632 23463 118668 4...
# 1       35753 27736 146603 73055 11794 101761 11794 81...
# 2       114413 107973 117252 27736 41035 32715 125374 ...
# 3       60473 9864 8109 135558 108803 89307 37630 6481...
# 4       105860 4691 134820 55911 80449 79213 23233 139...
# ...                                                   ...
# ...

# %% [markdown]
# ## columns

# %%
df_feed_info.columns.to_list()
# Out:
# ['feedid',
#  'authorid',
#  'videoplayseconds',
#  'description',
#  'ocr',
#  'asr',
#  'bgm_song_id',
#  'bgm_singer_id',
#  'manual_keyword_list',
#  'machine_keyword_list',
#  'manual_tag_list',
#  'machine_tag_list',
#  'description_char',
#  'ocr_char',
#  'asr_char']

# %% [markdown]
# ## feed embeddings

# %%
df_feed_embeddings = pd.read_csv('data/wechat_algo_data1/feed_embeddings.csv')

# %%
df_feed_embeddings
# Out:
#         feedid                                     feed_embedding
# 0        46022  -0.02032269 0.06095614 0.11057708 0.03385210 0...
# 1        73903  -0.07594238 0.01796364 -0.00135112 -0.00333468...
# 2        88646  -0.05067272 -0.08208735 -0.01929738 -0.0150182...
# 3        24381  -0.06976026 0.00218324 0.04416835 0.06146711 -...
# 4        41542  -0.04981736 -0.03523079 0.03022859 0.06672543 ...
# ...        ...                                                ...
# 106439   14792  -0.00801850 0.03034283 0.09088695 -0.01049765 ...
# 106440   42659  -0.02209187 -0.05218977 0.04746873 -0.07294663...
# 106441   66410  -0.00619426 0.00436533 0.02677129 -0.02013679 ...
# 106442    7919  -0.05661627 -0.13232523 -0.03405083 0.02689592...
# 106443   30814  -0.03162132 0.01220179 -0.03419615 0.04179954 ...
#
# [106444 rows x 2 columns]

# %% [markdown]
# # test_a

# %%
df_test_a = pd.read_csv('data/wechat_algo_data1/test_a.csv')

# %%
df_test_a
# Out:
#         userid  feedid  device
# 0        14298   67227       1
# 1        68356   91864       2
# 2        49925  104657       2
# 3        60529   23738       2
# 4       131482   69038       1
# ...        ...     ...     ...
# 421980  133812   56450       2
# 421981  231669   76501       1
# 421982  179168   70550       2
# 421983   92546   49432       2
# 421984  205434    2109       1
#
# [421985 rows x 3 columns]

# %%
df_test_a.groupby('userid').agg(cnt=('feedid','count'))
# Out:
#         cnt
# userid
# 25        5
# 71       32
# 76       36
# 108      85
# 130       9
# ...     ...
# 250129   46
# 250144   29
# 250160    2
# 250168   15
# 250224    7
#
# [9757 rows x 1 columns]

# %% [markdown]
# ## 部分人有连个个device

# %%
(
    df_test_a
    .groupby(['userid','device']).agg(cnt=('feedid','count'))
    .reset_index()
    .groupby('userid').agg(cnt2=('device','count'))
    .query('cnt2 == 2')
)
# Out:
#         cnt2
# userid
# 22766      2
# 58663      2
# 126421     2
# 137131     2
# 210617     2
# 244102     2

# %% [markdown]
# # user_train vs user_test

# %%
test_user_ls = df_test_a.userid.unique()
len(test_user_ls)
# Out:
# 9757

# %%
train_user_ls = df_user_action.userid.unique()
len(train_user_ls)
# Out:
# 20000

# %%
set(test_user_ls) - set(train_user_ls)
# Out:
# set()

# %%
len(set(train_user_ls) - set(test_user_ls))
# Out:
# 10243

# %% [markdown]
# # feature

# %% [markdown]
# ## feedid_feature

# %%
df_feedid_feature = pd.read_csv('data/feature/feedid_feature.csv')

# %%
df_feedid_feature
# Out:
#         feedid  read_commentsum  likesum  click_avatarsum  forwardsum  \
# 0            0                0        0                0           0
# 1            1                2        0                0           0
# 2            3                0        1                0           0
# 3            4                0        0                1           0
# 4            6                0        0                0           0
# ...        ...              ...      ...              ...         ...
# 772507  112866                1        0                0           0
# 772508  112868               35       11                0           1
# 772509  112869                1        2                0           0
# 772510  112870                0        1                0           0
# 772511  112871                0        0                0           0
#
#         commentsum  followsum  favoritesum  date_
# 0                0          0            0      8
# ...

# %%
df_feedid_feature.date_.value_counts()
# Out:
# 8     96564
# 9     96564
# 10    96564
# 11    96564
# 12    96564
# 13    96564
# 14    96564
# 15    96564
# Name: date_, dtype: int64

# %% [markdown]
# ## userid_feature

# %%
df_userid_feature = pd.read_csv('data/feature/userid_feature.csv')
df_userid_feature
# Out:
#         userid  read_commentsum  likesum  click_avatarsum  forwardsum  \
# 0            8                0       38                0           0
# 1           12               76        8                1           2
# 2           13               98        3                0           0
# 3           25                0        7                0           0
# 4           37                0        0                0           3
# ...        ...              ...      ...              ...         ...
# 159995  250207               84       31                3           0
# 159996  250221                0        5                0           0
# 159997  250224                0       66                0           1
# 159998  250229                0        0                0           1
# 159999  250236               53        0                6           0
#
#         commentsum  followsum  favoritesum  date_
# 0                0          0            0      8
# ...

# %% [markdown]
# # sample

# %% [markdown]
# ## generate sample
# ### offline_train_like_12_generate_sample

# %%
df_offline_sample = pd.read_csv('data/offline_train/offline_train_like_12_generate_sample.csv')

# %%
df_offline_sample
# Out:
#         userid  feedid  date_  device  like
# 0       151650  111533      8       1     0
# 1       171153   87874      8       1     0
# 2        56672   26773      9       2     0
# 3       176159   16687     11       1     0
# 4       121363   86324     10       2     0
# ...        ...     ...    ...     ...   ...
# 596599  250224   19030     12       2     1
# 596600  250224   10635     12       2     1
# 596601  250224   92120     12       2     1
# 596602  250224   75401     12       2     1
# 596603  250224   26643     12       2     1
#
# [596604 rows x 5 columns]

# %%
df_offline_sample.like.value_counts()
# Out:
# 0    527878
# 1     68726
# Name: like, dtype: int64

# %%
pd.read_csv('data/offline_train/offline_train_forward_12_generate_sample.csv')
# Out:
#         userid  feedid  date_  device  forward
# 0       148116   73852     11       2        0
# 1       113614  111498     11       2        0
# 2       147589   36987      8       2        0
# 3       182521   80805     11       1        0
# 4       220658   13265     11       2        0
# ...        ...     ...    ...     ...      ...
# 279492  249990   21854     11       2        1
# 279493  250069   69546     12       2        1
# 279494  250069   64543     12       2        1
# 279495  250160   12809     10       2        1
# 279496  250229   92707     12       1        1
#
# [279497 rows x 5 columns]

# %%
pd.read_csv('data/offline_train/offline_train_forward_12_generate_sample.csv').forward.value_counts()
# Out:
# 0    269846
# 1      9651
# Name: forward, dtype: int64

# %% [markdown]
# ## concat sample

# %%
df_concat_sample = pd.read_csv('data/offline_train/offline_train_forward_12_concate_sample.csv')
df_concat_sample
# Out:
#         userid  feedid  device  authorid  bgm_song_id  bgm_singer_id  \
# 0       148116   73852       2      2884        18174           7780
# 1       113614  111498       2     12469            0              0
# 2       147589   36987       2     14476            0              0
# 3       182521   80805       1      5178            0              0
# 4       220658   13265       2      3184            0              0
# ...        ...     ...     ...       ...          ...            ...
# 279492  249990   21854       2     13546         6667           5641
# 279493  250069   69546       2     17818        16561           2622
# 279494  250069   64543       2      2903            0              0
# 279495  250160   12809       2      6087        21584           2318
# 279496  250229   92707       1      8246         5274          10844
#
#         videoplayseconds  forward  read_commentsum   likesum  ...  commentsum  \
# ...

# %%
df_concat_sample.head().T
# Out:
#                                   0              1              2  \
# userid                148116.000000  113614.000000  147589.000000
# feedid                 73852.000000  111498.000000   36987.000000
# device                     2.000000       2.000000       2.000000
# authorid                2884.000000   12469.000000   14476.000000
# bgm_song_id            18174.000000       0.000000       0.000000
# bgm_singer_id           7780.000000       0.000000       0.000000
# videoplayseconds           2.397895       4.110874       2.944439
# forward                    0.000000       0.000000       0.000000
# read_commentsum            0.000000       3.526361       0.000000
# likesum                    0.000000       2.639057       2.708050
# click_avatarsum            0.000000       1.609438       0.693147
# forwardsum                 0.000000       0.000000       0.693147
# commentsum                 0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # function imp
# ## statis_feature

# %%
df_user_action.columns.values
# Out:
# array(['userid', 'feedid', 'date_', 'device', 'read_comment', 'comment',
#        'like', 'play', 'stay', 'click_avatar', 'forward', 'follow',
#        'favorite'], dtype=object)

# %%
list(map(''.join, df_user_action.columns.values))
# Out:
# ['userid',
#  'feedid',
#  'date_',
#  'device',
#  'read_comment',
#  'comment',
#  'like',
#  'play',
#  'stay',
#  'click_avatar',
#  'forward',
#  'follow',
#  'favorite']

# %%
df_user_action.groupby(['userid']).agg(['sum']).columns.values
# Out:
# array([('feedid', 'sum'), ('date_', 'sum'), ('device', 'sum'),
#        ('read_comment', 'sum'), ('comment', 'sum'), ('like', 'sum'),
#        ('play', 'sum'), ('stay', 'sum'), ('click_avatar', 'sum'),
#        ('forward', 'sum'), ('follow', 'sum'), ('favorite', 'sum')],
#       dtype=object)

# %%
list(map(''.join, df_user_action.groupby(['userid']).agg(['sum']).columns.values))
# Out:
# ['feedidsum',
#  'date_sum',
#  'devicesum',
#  'read_commentsum',
#  'commentsum',
#  'likesum',
#  'playsum',
#  'staysum',
#  'click_avatarsum',
#  'forwardsum',
#  'followsum',
#  'favoritesum']

# %% [markdown]
# ## generate_sample
